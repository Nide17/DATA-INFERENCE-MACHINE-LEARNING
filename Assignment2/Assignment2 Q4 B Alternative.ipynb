# %%
# Importing libraries to use
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

fertilityRate = pd.read_excel('./parmenin/fertility.xls', sheet_name = 'Data', skiprows = 3)  # Reading fertility data from excel file
gdpPerCapita = pd.read_excel('./parmenin/gdp.xls', sheet_name = 'Data', skiprows = 3)         # Reading gdp data from excel file

# Extracting only Country Name and the year 2010 and 1990 to use
fertExtracted1990 = fertilityRate[['Country Name', '1990']]
fertExtracted2010 = fertilityRate[['Country Name', '2010']]

# Sorting the data to use while plotting the distribution
fertSorted1990 = np.sort(fertExtracted1990['1990'])
fertSorted2010 = np.sort(fertExtracted2010['2010'])

# Finding the fertility rate's cumulative distribution functions for 1990 & 2010
fertCDF1990 = np.cumsum(fertSorted1990) / fertExtracted1990['1990'].sum()
fertCDF2010 = np.cumsum(fertSorted2010) / fertExtracted2010['2010'].sum()

# Finding the mean
mean1990 = fertExtracted1990['1990'].mean()
mean2010 = fertExtracted2010['2010'].mean()

# Finding the median
median1990 = fertExtracted1990['1990'].median()
median2010 = fertExtracted2010['2010'].median()

# Plotting: Defining figure properties
plt.figure(figsize = (14, 8), edgecolor = 'r', facecolor = 'y', linewidth = 1)

# Plotting on the same axes cumulative distribution functions for the fertility rate variable using 1990 & 2010 data
plt.plot(fertSorted1990, fertCDF1990, color = 'black', label = 'Year 1990 distribution')
plt.plot(fertSorted2010, fertCDF2010, color = 'green', label = 'Year 2010 distribution')

# Plotting the mean using vertical lines 
plt.axvline(x = mean1990, color = 'red', label = 'Mean for 1990', linestyle = '-', linewidth = 1.5, ymin = 0.02, ymax = 0.97)
plt.axvline(x = mean2010, color = 'blue', label = 'Mean for 2010', linestyle = '-', linewidth = 1.5, ymin = 0.02, ymax = 0.97)

# Plotting the median using vertical lines 
plt.axvline(x = median1990, color = 'pink', label = 'Median for 1990', linestyle = '-', linewidth = 1.5, ymin = 0.02, ymax = 0.97)
plt.axvline(x = median2010, color = 'aqua', label = 'Median for 2010', linestyle = '-', linewidth=1.5, ymin = 0.02, ymax = 0.97)

# Adding the title and labels to the plot
plt.title("CUMULATIVE DISTRIBUTION FUNCTIONS FOR THE FERTILITY RATE IN 1990 & 2010")
plt.ylabel("CUMULATIVE DISTRIBUTION")
plt.xlabel("FERTILITY RATE")

plt.legend()
plt.show()

# %%
HPI2016 = pd.read_excel('./parmenin/hpi-data-2016.xlsx', sheet_name = 'Complete HPI data', skiprows = 5) 
CPI2016 = pd.read_excel('./parmenin/CPI2016_Results.xlsx', sheet_name = 'CPI2016_FINAL_16Jan') 

HPI_CPI = pd.merge(HPI2016, CPI2016, on = 'Country')
hpiRank = HPI_CPI['HPI Rank']
cpiRank = HPI_CPI['Rank']

# Plotting: Defining figure properties
plt.figure(figsize = (14, 9), edgecolor = 'r', facecolor = 'y', linewidth = 1)

# Adding the title and labels to the plot
plt.title("RELATIONSHIP BETWEEN HPI AND CPI BY RANKING")
plt.ylabel("Happy Planet Index")
plt.xlabel("Corruption Perception Index")

plt.scatter(cpiRank, hpiRank, label = 'HPI against CPI Ranks', color = 'green', s = 100, marker = 'o')

for index, cCode in enumerate(HPI_CPI['WB Code']):
    plt.annotate(cCode, (cpiRank[index], hpiRank[index]))

plt.show()
# Out:
# C:\Users\Parmenide\AppData\Local\Programs\Python\Python310\lib\site-packages\openpyxl\worksheet\_reader.py:312: UserWarning: Conditional Formatting extension is not supported and will be removed
#   warn(msg)

# %%
# Importing libraries to use
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

fertilityRate = pd.read_excel('./parmenin/fertility.xls', sheet_name = 'Data', skiprows = 3)  # Reading fertility data from excel file
gdpPerCapita = pd.read_excel('./parmenin/gdp.xls', sheet_name = 'Data', skiprows = 3)         # Reading gdp data from excel file

# Extracting only Country Name and the year 2010 and 1990 to use
fertExtracted1990 = fertilityRate[['Country Name', '1990']]
fertExtracted2010 = fertilityRate[['Country Name', '2010']]

# Sorting the data to use while plotting the distribution
fertSorted1990 = np.sort(fertExtracted1990['1990'])
fertSorted2010 = np.sort(fertExtracted2010['2010'])

# Finding the fertility rate's cumulative distribution functions for 1990 & 2010
fertCDF1990 = np.cumsum(fertSorted1990) / fertExtracted1990['1990'].sum()
fertCDF2010 = np.cumsum(fertSorted2010) / fertExtracted2010['2010'].sum()

# print(np.cumsum(fertSorted1990))
# print(fertExtracted2010['2010'].sum())
print(fertSorted1990)

# Finding the mean
mean1990 = fertExtracted1990['1990'].mean()
mean2010 = fertExtracted2010['2010'].mean()

# Finding the median
median1990 = fertExtracted1990['1990'].median()
median2010 = fertExtracted2010['2010'].median()

# Plotting: Defining figure properties
plt.figure(figsize = (14, 8), edgecolor = 'r', facecolor = 'y', linewidth = 1)

# Plotting on the same axes cumulative distribution functions for the fertility rate variable using 1990 & 2010 data
plt.plot(fertSorted1990, fertCDF1990, color = 'black', label = 'Year 1990 distribution')
plt.plot(fertSorted2010, fertCDF2010, color = 'green', label = 'Year 2010 distribution')

# Plotting the mean using vertical lines 
plt.axvline(x = mean1990, color = 'red', label = 'Mean for 1990', linestyle = '-', linewidth = 1.5, ymin = 0.02, ymax = 0.97)
plt.axvline(x = mean2010, color = 'blue', label = 'Mean for 2010', linestyle = '-', linewidth = 1.5, ymin = 0.02, ymax = 0.97)

# Plotting the median using vertical lines 
plt.axvline(x = median1990, color = 'pink', label = 'Median for 1990', linestyle = '-', linewidth = 1.5, ymin = 0.02, ymax = 0.97)
plt.axvline(x = median2010, color = 'aqua', label = 'Median for 2010', linestyle = '-', linewidth=1.5, ymin = 0.02, ymax = 0.97)

# Adding the title and labels to the plot
plt.title("CUMULATIVE DISTRIBUTION FUNCTIONS FOR THE FERTILITY RATE IN 1990 & 2010")
plt.ylabel("CUMULATIVE DISTRIBUTION")
plt.xlabel("FERTILITY RATE")

plt.legend()
plt.show()
# Out:
# [1.272      1.33       1.36       1.39       1.45       1.46
#  1.46       1.483      1.53425069 1.54       1.56       1.57
#  1.58       1.6        1.62       1.62       1.63       1.63480306
#  1.67       1.714      1.722      1.74       1.74936962 1.77
#  1.772      1.78       1.82       1.83       1.83       1.83
#  1.83       1.85       1.8514046  1.87       1.892      1.9
#  1.902      1.913      1.93       1.93108193 1.95793165 2.013754
#  2.02       2.02       2.03       2.05       2.05520556 2.06
#  2.067      2.078      2.081      2.09       2.11       2.113
#  2.12       2.13       2.18       2.18       2.206      2.219
#  2.249      2.289      2.3        2.309      2.3090406  2.32
#  2.37661925 2.411      2.414      2.42703593 2.444      2.453
#  2.47193007 2.483      2.52       2.544      2.54650959 2.579
#  2.58722025 2.59130631 2.64       2.72       2.74       2.8
#  2.824      2.84       2.86576574 2.902      2.947      2.954
#  2.956      2.967      2.978      2.997      3.013      3.057
#  3.069      3.07688951 3.082      3.107      3.122      3.18
#  3.24854713 3.25701813 3.264      3.267      3.29       3.29254466
#  3.31047149 3.372      3.39711963 3.398      3.399      3.401
#  3.411      3.447      3.448      3.47       3.476      3.553
#  3.554      3.57826728 3.59776345 3.63       3.732      3.744
#  3.842      3.9        3.912      3.964      3.964      4.00769924
#  4.013      4.045      4.047      4.052      4.072      4.22514377
#  4.2998973  4.2998973  4.30331259 4.32       4.344      4.36023704
#  4.39049029 4.454      4.485      4.495      4.508      4.547
#  4.58       4.596      4.644      4.688      4.691      4.721
#  4.726      4.802      4.85893376 4.862      4.87459072 4.87763143
#  4.89       4.926      4.958      4.966      5.106      5.118
#  5.119      5.123      5.172      5.1868314  5.219      5.225
#  5.309      5.392      5.43       5.437      5.442      5.478
#  5.493      5.521      5.58681146 5.601      5.602      5.811
#  5.828      5.851      5.85982775 5.881      5.882      5.911
#  5.91159018 5.94378458 5.987      6.003      6.01678295 6.066
#  6.073      6.096      6.151      6.152      6.164      6.179
#  6.185      6.211      6.213      6.23490096 6.34772998 6.34772998
#  6.34772998 6.412      6.436      6.442      6.448      6.48318266
#  6.49       6.496      6.499      6.51814633 6.57327767 6.58926281
#  6.598      6.622      6.627      6.718      6.721      6.744
#  6.746      6.761      6.872      7.007      7.091      7.165
#  7.165      7.184      7.246      7.272      7.313      7.398
#  7.405      7.466      7.772      8.606             nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan]
